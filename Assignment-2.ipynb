# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('../data/Train.csv')
data
# Out:
#       Package Type                                  Destination  \
# 0         Standard           New Delhi|Shimla|Manali|Chandigarh
# 1          Premium                   Srinagar|Pahalgam|Srinagar
# 2           Luxury                          Udaipur|Chittorgarh
# 3          Premium  Munnar|Kumarakom|Allepey|Kovalam and Poovar
# 4          Premium                              Pattaya|Bangkok
# ...            ...                                          ...
# 20995       Deluxe                      Shimla|Manali|New Delhi
# 20996       Luxury           Srinagar|Gulmarg|Pahalgam|Srinagar
# 20997       Deluxe                                      Colombo
# 20998       Deluxe                   Darjeeling|Pelling|Gangtok
# 20999     Standard                       Munnar|Kovalam|Allepey
#
#                                                Itinerary Travel Date  \
# 0      1N New Delhi . 2N Shimla . 2N Manali . 1N Chan...  30-07-2021
# ...

# %% [markdown]
# ### TransForm These data Into Trainable Data
# #### Apply pre processing techniques
# ##### Here None of The Features Are Co-Related So, Don't Drop any of the Features

# %%
data.isnull().sum()
# Out:
# Package Type    0
# Destination     0
# Itinerary       0
# Travel Date     0
# Start City      0
# Airline         0
# Flight Stops    0
# Meals           0
# dtype: int64

# %%
data.shape
# Out:
# (21000, 8)

# %%
#one hot encoding
pd.get_dummies(data['Start City'])
# Out:
#        Mumbai  New Delhi
# 0           1          0
# 1           0          1
# 2           0          1
# 3           0          1
# 4           0          1
# ...       ...        ...
# 20995       1          0
# 20996       0          1
# 20997       0          1
# 20998       0          1
# 20999       0          1
#
# [21000 rows x 2 columns]

# %%
data2 = data[['Airline','Start City','Package Type']]
data2
# Out:
#                            Airline Start City Package Type
# 0                    Not Available     Mumbai     Standard
# 1                    IndiGo|IndiGo  New Delhi      Premium
# 2                           IndiGo  New Delhi       Luxury
# 3                           IndiGo  New Delhi      Premium
# 4                  Spicejet|Go Air  New Delhi      Premium
# ...                            ...        ...          ...
# 20995                Not Available     Mumbai       Deluxe
# 20996              Vistara|Vistara  New Delhi       Luxury
# 20997  IndiGo|IndiGo|IndiGo|IndiGo  New Delhi       Deluxe
# 20998                       IndiGo  New Delhi       Deluxe
# 20999                       IndiGo  New Delhi     Standard
#
# [21000 rows x 3 columns]

# %%
LabelEncoder().fit_transform(data2['Start City'])
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
data2['Start City Encoded'] = LabelEncoder().fit_transform(data2['Start City'])
data2
# Out:
# <ipython-input-39-df4cb9fd085c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Start City Encoded'] = LabelEncoder().fit_transform(data2['Start City'])
#                            Airline Start City Package Type  \
# 0                    Not Available     Mumbai     Standard
# 1                    IndiGo|IndiGo  New Delhi      Premium
# 2                           IndiGo  New Delhi       Luxury
# 3                           IndiGo  New Delhi      Premium
# 4                  Spicejet|Go Air  New Delhi      Premium
# ...                            ...        ...          ...
# 20995                Not Available     Mumbai       Deluxe
# 20996              Vistara|Vistara  New Delhi       Luxury
# ...

# %%
data['Package Type'].unique()
# Out:
# array(['Standard', 'Premium', 'Luxury', 'Deluxe', 'Budget'], dtype=object)

# %%
label = {'Budget': 0, 'Standard': 1, 'Deluxe': 3, 'Luxury': 4, 'Premium': 5}

# %%
data2['Package Type Encoded'] = data2['Package Type'].map(label)
data2
# Out:
# <ipython-input-40-e0bdd1465347>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['